# %%
import pandas as pd
import matplotlib.pyplot as plt 
from google.colab import files

# %%
dataset = "sample_data/california_housing_train.csv" 
dataframe = pd.read_csv(dataset)
dataframe.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
# Perform discretization.
dataframe['pop_class'] = pd.cut(dataframe[ 'median_house_value'], 5, labels = ['poor', 'lower-middle-class', 'middle-class', 'upper-middle-class', 'rich'])

# %%
dataframe.sample(20)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16472    -122.62     38.73                21.0       1425.0           323.0
# 2236     -117.40     33.94                37.0        987.0           187.0
# 2108     -117.35     34.15                32.0       2699.0           552.0
# 10029    -119.78     36.30                30.0       1846.0           391.0
# 4284     -118.01     34.11                32.0       1978.0           536.0
# 13730    -122.00     37.37                16.0       1434.0           372.0
# 5209     -118.13     33.80                36.0       1026.0           182.0
# 4106     -117.98     33.83                17.0       3419.0           932.0
# 9496     -119.29     36.34                35.0       1235.0           369.0
# 3297     -117.87     33.92                14.0       4039.0           669.0
# 10618    -120.47     34.64                16.0       1912.0           406.0
# ...

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e2facb43-2076-4679-802d-b465222d7482" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2facb43-2076-4679-802d-b465222d7482">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
new_dataframe = pd.read_csv('fifa.csv')[['short_name', 'age', 'overall', 'potential', 'value_eur']]

# %%
new_dataframe.describe()
# Out:
#                 age       overall     potential     value_eur
# count  16155.000000  16155.000000  16155.000000  1.615500e+04
# mean      24.776230     63.830393     68.350108  1.060882e+06
# std        4.625321      7.169896      6.580610  2.819128e+06
# min       16.000000     40.000000     40.000000  0.000000e+00
# 25%       21.000000     59.000000     64.000000  1.200000e+05
# 50%       24.000000     64.000000     68.000000  3.500000e+05
# 75%       28.000000     68.000000     73.000000  8.250000e+05
# max       44.000000     93.000000     95.000000  1.005000e+08

# %%
# Histogram 
# Select bins. 
bins = [40, 50, 60, 70, 80, 90, 100]
# Plot histogram
plt.hist(new_dataframe. overall, bins = bins)
# Plot details
plt.title("overall distribution in Fifa 2021") 
plt.xlabel("Player overall rating.") 
plt.ylabel("Number of players.")
plt.xticks (bins)
# Display the plot. plt.show()
# Out:
# ([<matplotlib.axis.XTick at 0x7f7d368addd0>,
# ...
#  <a list of 7 Text major ticklabel objects>)
